# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import pmdarima as pm
import numpy as np
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA

# %%
#ACF AND PACF graphs:

# Read the CSV file into a DataFrame
data = pd.read_csv("C:\\Users\\Patri\\Desktop\\SARIMA\\passenger_data.csv")

# Extract the relevant column 
series = data[]

# Plot the autocorrelation function
plot_acf(series, lags=5)

# %%
#Akaike Information Criterion Test

# Input your data
data = np.array()


# Fit the auto SARIMA model
model = pm.auto_arima(data, seasonal=True, trace=True, suppress_warnings=True)


# Print the model summary
print(model.summary())

# %%
#Augmented Dickey-Fuller Test:

result = adfuller()

print('Augmented Dickey-Fuller Test:')
print('ADF Statistic:', result[0])
print('p-value:', result[1])
